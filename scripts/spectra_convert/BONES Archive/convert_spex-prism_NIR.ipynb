# %%
import astropy.units as u
from specutils import Spectrum1D
from astrodb_utils.spectra import check_spectrum_plottable
import os
import numpy as np

# %%
path = "/Users/guanying/SIMPLE_Archive/SIMPLE-db/scripts/spectra_convert/BONES Archive/BONES SPECTRA/"

# %%
# Process source with spex-prism_NIR files
file_plotted = 0
file_failed = 0

for filename in os.listdir(path):
    if filename.startswith("spex-prism_NIR") and filename.endswith(".txt"):
        print(f"Processing {filename}")
        file_path = os.path.join(path, filename)
        data = np.loadtxt(file_path, comments="#", encoding="latin1")

        wavelength = data[:, 0] * u.AA
        flux = data[:, 1] * (u.erg / u.cm**2 / u.s / u.AA)

        spectrum = Spectrum1D(flux=flux, spectral_axis=wavelength)

        if (check_spectrum_plottable(spectrum, show_plot=True)):
            print(f"{filename} is plottable\n")
            file_plotted += 1
        else:
            file_failed += 1

print(f"Ploted files: {file_plotted}")
print(f"Failed files: {file_failed}")
# Out:
# Processing spex-prism_NIR_J0330+3505_Bardalez2014.txt
# spex-prism_NIR_J0330+3505_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J0330-2348_Bardalez2014.txt
# spex-prism_NIR_J0330-2348_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J1416+1348B_Burg2010.txt
# spex-prism_NIR_J1416+1348B_Burg2010.txt is plottable
#
# Processing spex-prism_NIR_J1541+5425_Burgasser2004.txt
# spex-prism_NIR_J1541+5425_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1556+1300_Burgasser2004.txt
# spex-prism_NIR_J1556+1300_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1640+1231_Burgasser2004.txt
# spex-prism_NIR_J1640+1231_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1756+2815_Kirkpatrick2010.txt
# spex-prism_NIR_J1756+2815_Kirkpatrick2010.txt is plottable
#
# Processing spex-prism_NIR_J1826+3014_Bardalez2014.txt
# spex-prism_NIR_J1826+3014_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J0306-0330_Kirkpatrick2014.txt
# spex-prism_NIR_J0306-0330_Kirkpatrick2014.txt is plottable
#
# Processing spex-prism_NIR_J0435+2115_Luhman2014.txt
# spex-prism_NIR_J0435+2115_Luhman2014.txt is plottable
#
# Processing spex-prism_NIR_J0115+3130_Burgasser2004.txt
# spex-prism_NIR_J0115+3130_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1013-1356_Burgasser2004.txt
# spex-prism_NIR_J1013-1356_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1444-2019_Kirkpatrick2016.txt
# spex-prism_NIR_J1444-2019_Kirkpatrick2016.txt is plottable
#
# Processing spex-prism_NIR_J1439+1839_Burgasser2004.txt
# spex-prism_NIR_J1439+1839_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1640+2922_Burgasser2004.txt
# spex-prism_NIR_J1640+2922_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J1158+0435_Kirkpatrick2010.txt
# spex-prism_NIR_J1158+0435_Kirkpatrick2010.txt is plottable
#
# Processing spex-prism_NIR_J0447-1946_Kirkpatrick2010.txt
# spex-prism_NIR_J0447-1946_Kirkpatrick2010.txt is plottable
#
# Processing spex-prism_NIR_J0142+0523_Burgasser2004.txt
# spex-prism_NIR_J0142+0523_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J0452-2245_Burgasser2006.txt
# spex-prism_NIR_J0452-2245_Burgasser2006.txt is plottable
#
# Processing spex-prism_NIR_J0333+0014_Bardalez2014.txt
# spex-prism_NIR_J0333+0014_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J2347+0219_Kirkpatrick2010.txt
# spex-prism_NIR_J2347+0219_Kirkpatrick2010.txt is plottable
#
# Processing spex-prism_NIR_J0402+1730_Bardalez2014.txt
# spex-prism_NIR_J0402+1730_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J1256-0224_Burgasser2009.txt
# spex-prism_NIR_J1256-0224_Burgasser2009.txt is plottable
#
# Processing spex-prism_NIR_J0459+1540_Kirkpatrick2014.txt
# spex-prism_NIR_J0459+1540_Kirkpatrick2014.txt is plottable
#
# Processing spex-prism_NIR_J2036+5059_Burgasser2004.txt
# spex-prism_NIR_J2036+5059_Burgasser2004.txt is plottable
#
# Processing spex-prism_NIR_J2331+4607_Bardalez2014.txt
# spex-prism_NIR_J2331+4607_Bardalez2014.txt is plottable
#
# Processing spex-prism_NIR_J2040+6959_Luhman2014.txt
# spex-prism_NIR_J2040+6959_Luhman2014.txt is plottable
#
# Processing spex-prism_NIR_J1626+3925_Burgasser2004.txt
# spex-prism_NIR_J1626+3925_Burgasser2004.txt is plottable
#
# Ploted files: 28
# Failed files: 0
